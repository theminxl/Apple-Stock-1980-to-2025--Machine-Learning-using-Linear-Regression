# %%
import kagglehub
path = kagglehub.dataset_download("umerhaddii/apple-stock-data-2025")
# Out:
# ...
# 100%|██████████| 301k/301k [00:00<00:00, 108MB/s]
# Extracting files...

# %%
import os
os.listdir(path)
# Out:
# ['apple_stock.csv']

# %%
import pandas as pd
file_path = path + '/apple_stock.csv'

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0  Adj Close     Close      High       Low      Open     Volume
# 0  1980-12-12   0.098834  0.128348  0.128906  0.128348  0.128348  469033600
# 1  1980-12-15   0.093678  0.121652  0.122210  0.121652  0.122210  175884800
# 2  1980-12-16   0.086802  0.112723  0.113281  0.112723  0.113281  105728000
# 3  1980-12-17   0.088951  0.115513  0.116071  0.115513  0.115513   86441600
# 4  1980-12-18   0.091530  0.118862  0.119420  0.118862  0.118862   73449600

# %%
df
# Out:
#        Unnamed: 0   Adj Close       Close        High         Low        Open  \
# 0      1980-12-12    0.098834    0.128348    0.128906    0.128348    0.128348
# 1      1980-12-15    0.093678    0.121652    0.122210    0.121652    0.122210
# 2      1980-12-16    0.086802    0.112723    0.113281    0.112723    0.113281
# 3      1980-12-17    0.088951    0.115513    0.116071    0.115513    0.115513
# 4      1980-12-18    0.091530    0.118862    0.119420    0.118862    0.118862
# ...           ...         ...         ...         ...         ...         ...
# 11102  2024-12-27  255.589996  255.589996  258.700012  253.059998  257.829987
# 11103  2024-12-30  252.199997  252.199997  253.500000  250.750000  252.229996
# 11104  2024-12-31  250.419998  250.419998  253.279999  249.429993  252.440002
# 11105  2025-01-02  243.850006  243.850006  249.100006  241.820007  248.929993
# 11106  2025-01-03  243.860001  243.860001  244.179993  241.889999  243.369995
#
#           Volume
# ...

# %%
data = pd.read_csv(file_path) # Reload data to ensure 'Unnamed: 0' is present
data.rename(columns={'Unnamed: 0': 'date'}, inplace=True)
data['date'] = pd.to_datetime(data['date'])
# data['year'] = data['date'].dt.year FOR EXTRACTING YEARS

# %%
data
# Out:
#             date   Adj Close       Close        High         Low        Open  \
# 0     1980-12-12    0.098834    0.128348    0.128906    0.128348    0.128348
# 1     1980-12-15    0.093678    0.121652    0.122210    0.121652    0.122210
# 2     1980-12-16    0.086802    0.112723    0.113281    0.112723    0.113281
# 3     1980-12-17    0.088951    0.115513    0.116071    0.115513    0.115513
# 4     1980-12-18    0.091530    0.118862    0.119420    0.118862    0.118862
# ...          ...         ...         ...         ...         ...         ...
# 11102 2024-12-27  255.589996  255.589996  258.700012  253.059998  257.829987
# 11103 2024-12-30  252.199997  252.199997  253.500000  250.750000  252.229996
# 11104 2024-12-31  250.419998  250.419998  253.279999  249.429993  252.440002
# 11105 2025-01-02  243.850006  243.850006  249.100006  241.820007  248.929993
# 11106 2025-01-03  243.860001  243.860001  244.179993  241.889999  243.369995
#
#           Volume
# 0      469033600
# ...

# %%
data.head()
# Out:
#         date  Adj Close     Close      High       Low      Open     Volume
# 0 1980-12-12   0.098834  0.128348  0.128906  0.128348  0.128348  469033600
# 1 1980-12-15   0.093678  0.121652  0.122210  0.121652  0.122210  175884800
# 2 1980-12-16   0.086802  0.112723  0.113281  0.112723  0.113281  105728000
# 3 1980-12-17   0.088951  0.115513  0.116071  0.115513  0.115513   86441600
# 4 1980-12-18   0.091530  0.118862  0.119420  0.118862  0.118862   73449600

# %%
df.shape
# Out:
# (11107, 7)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11107 entries, 0 to 11106
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11107 non-null  object
#  1   Adj Close   11107 non-null  float64
#  2   Close       11107 non-null  float64
#  3   High        11107 non-null  float64
#  4   Low         11107 non-null  float64
#  5   Open        11107 non-null  float64
#  6   Volume      11107 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 607.5+ KB

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0     Adj Close         Close          High           Low  \
# count        11107  11107.000000  11107.000000  11107.000000  11107.000000
# unique       11107           NaN           NaN           NaN           NaN
# top     2025-01-03           NaN           NaN           NaN           NaN
# freq             1           NaN           NaN           NaN           NaN
# mean           NaN     23.522229     24.357607     24.598169     24.092608
# std            NaN     49.767881     50.217498     50.691902     49.682631
# min            NaN      0.037815      0.049107      0.049665      0.049107
# 25%            NaN      0.243402      0.300290      0.306362      0.292411
# 50%            NaN      0.446682      0.542411      0.553393      0.534598
# 75%            NaN     18.260086     21.397143     21.569285     21.115715
# max            NaN    259.019989    259.019989    260.100006    257.630005
#
#                 Open        Volume
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Adj Close     0
# Close         0
# High          0
# Low           0
# Open          0
# Volume        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'berlin',
#  'managua',
#  'vanimo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#         Adj Close       Close        High         Low        Open     Volume
# 0        0.098834    0.128348    0.128906    0.128348    0.128348  469033600
# 1        0.093678    0.121652    0.122210    0.121652    0.122210  175884800
# 2        0.086802    0.112723    0.113281    0.112723    0.113281  105728000
# 3        0.088951    0.115513    0.116071    0.115513    0.115513   86441600
# 4        0.091530    0.118862    0.119420    0.118862    0.118862   73449600
# ...           ...         ...         ...         ...         ...        ...
# 11102  255.589996  255.589996  258.700012  253.059998  257.829987   42355300
# 11103  252.199997  252.199997  253.500000  250.750000  252.229996   35557500
# 11104  250.419998  250.419998  253.279999  249.429993  252.440002   39480700
# 11105  243.850006  243.850006  249.100006  241.820007  248.929993   55558000
# 11106  243.860001  243.860001  244.179993  241.889999  243.369995   15135053
#
# [11107 rows x 6 columns]

# %%
import numpy as np
a = df.corr()

# %%
sns.heatmap(a , cmap= 'mako')
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
new_df = df.drop('Volume', axis=1)

# %%
plt.figure(figsize=(20,10))
plt.hist(
    df[['Adj Close', 'Close', 'High', 'Low', 'Open']],
    label=['Adj Close', 'Close', 'High', 'Low', 'Open'],
    alpha = 0.7
)
plt.legend()

# %%
plt.hist(df[['Volume']])
# Out:
# (array([1.0091e+04, 8.6500e+02, 1.2100e+02, 2.3000e+01, 4.0000e+00,
#         2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([0.00000000e+00, 7.42164080e+08, 1.48432816e+09, 2.22649224e+09,
#         2.96865632e+09, 3.71082040e+09, 4.45298448e+09, 5.19514856e+09,
#         5.93731264e+09, 6.67947672e+09, 7.42164080e+09]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df[['Adj Close', 'Close', 'High', 'Low', 'Open']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e5f71c75970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e5f735e36e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e5f74269a00>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7e5f71c75eb0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7e5f71c76180>,
# ...
#  'means': []}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['date'], data[['Adj Close', 'Close', 'High', 'Low', 'Open']], label = ['Adj Close', 'Close', 'High', 'Low', 'Open'])
plt.xlabel('Date')
plt.ylabel('Prices')
plt.title('Apple Stock Prices Over Time')
plt.legend()
plt.grid(True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(data['date'], data['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Apple Stock Volume Over Time')
plt.grid(True)

# %%
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from mplfinance.original_flavor import candlestick_ohlc

# %%
import matplotlib.dates as mpdates
data['date_num'] = mpdates.date2num(data['date'])

# %%
ohlc = data[['date_num', 'Open', 'High', 'Low', 'Close']]

# %%
fig, ax = plt.subplots(figsize=(20,10))

candlestick_ohlc(
    ax,
    ohlc.values,
    width=0.6,
    colorup='green',
    colordown='red'
)

ax.xaxis_date()

plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')

plt.grid(True)

# %%
data['year'] = data['date'].dt.year
data_2007 = data[data['year'].isin([2006,2007,2008,2009,2010])]

# %%
# Filter one year
data_2020 = data[data['year'].isin([2006,2007,2008,2009,2010])]

# Required columns
ohlc = data_2007[['date_num', 'Open', 'High', 'Low', 'Close']]

# Plot
fig, ax = plt.subplots(figsize=(40,10))

candlestick_ohlc(
    ax,
    ohlc.values,
    width=0.6,
    colorup='green',
    colordown='red'
)

ax.xaxis_date()

plt.title('Candlestick Chart - 2006,2007,2008,2009,2010')
plt.grid(True)
plt.show()

# %%
data_2024 = data[data['year'] == 2024]

# %%
# Filter one year
data_2024 = data[data['year'] == 2024]

# Required columns
ohlc = data_2024[['date_num', 'Open', 'High', 'Low', 'Close']]

# Plot
fig, ax = plt.subplots(figsize=(20,10))

candlestick_ohlc(
    ax,
    ohlc.values,
    width=0.6,
    colorup='green',
    colordown='red'
)

ax.xaxis_date()

plt.title('Candlestick Chart - 2024')
plt.grid(True)
plt.show()

# %%
data_2025 = data[data['year'] == 2025]

# %%
# Filter one year
data_2025 = data[data['year'] == 2025]

# Required columns
ohlc = data_2025[['date_num', 'Open', 'High', 'Low', 'Close']]

# Plot
fig, ax = plt.subplots(figsize=(20,10))

candlestick_ohlc(
    ax,
    ohlc.values,
    width=0.6,
    colorup='green',
    colordown='red'
)

ax.xaxis_date()

plt.title('Candlestick Chart - 2025')
plt.grid(True)
plt.show()

# %%
X = df.drop('Close', axis=1)
y = df['Close']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_x, train_y)

# %%
y_pred = model.predict(test_x)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mae = mean_absolute_error(test_y, y_pred)
mse = mean_squared_error(test_y, y_pred)
r2 = r2_score(test_y, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)

# %%
adj_close = float(input("Enter Adj Close: "))
high = float(input("Enter High: "))
low = float(input("Enter Low: "))
open_price = float(input("Enter Open: "))
volume = float(input("Enter Volume: "))

# Create dataframe for prediction
new_data = pd.DataFrame({
    'Adj Close': [adj_close],
    'High': [high],
    'Low': [low],
    'Open': [open_price],
    'Volume': [volume]
})

# Predict Close price
prediction = model.predict(new_data)

print("Predicted Close Price:", prediction[0])
